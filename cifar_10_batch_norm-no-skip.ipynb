# %%
from cifar10_base import Net
from common import get_dst_device
from modelhelper import print_model_summary
device = get_dst_device()
model = Net().to(device)
print_model_summary(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             896
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#          Dropout2d-4           [-1, 32, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]           9,248
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#               ReLU-7           [-1, 32, 32, 32]               0
#          Dropout2d-8           [-1, 32, 32, 32]               0
#             Conv2d-9           [-1, 32, 32, 32]           1,056
#       BatchNorm2d-10           [-1, 32, 32, 32]              64
#              ReLU-11           [-1, 32, 32, 32]               0
#         Dropout2d-12           [-1, 32, 32, 32]               0
#         MaxPool2d-13           [-1, 32, 16, 16]               0
#            Conv2d-14           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-15           [-1, 32, 16, 16]              64
#              ReLU-16           [-1, 32, 16, 16]               0
#         Dropout2d-17           [-1, 32, 16, 16]               0
#            Conv2d-18           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-19           [-1, 32, 16, 16]              64
#              ReLU-20           [-1, 32, 16, 16]               0
#         Dropout2d-21           [-1, 32, 16, 16]               0
#            Conv2d-22           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-23           [-1, 32, 16, 16]              64
#              ReLU-24           [-1, 32, 16, 16]               0
#         Dropout2d-25           [-1, 32, 16, 16]               0
#            Conv2d-26           [-1, 32, 16, 16]           1,056
#       BatchNorm2d-27           [-1, 32, 16, 16]              64
#              ReLU-28           [-1, 32, 16, 16]               0
#         Dropout2d-29           [-1, 32, 16, 16]               0
#         MaxPool2d-30             [-1, 32, 8, 8]               0
#            Conv2d-31             [-1, 16, 8, 8]           4,624
#       BatchNorm2d-32             [-1, 16, 8, 8]              32
#              ReLU-33             [-1, 16, 8, 8]               0
#         Dropout2d-34             [-1, 16, 8, 8]               0
#            Conv2d-35             [-1, 16, 6, 6]           2,320
#       BatchNorm2d-36             [-1, 16, 6, 6]              32
#              ReLU-37             [-1, 16, 6, 6]               0
#         Dropout2d-38             [-1, 16, 6, 6]               0
#            Conv2d-39             [-1, 16, 4, 4]           2,320
#       BatchNorm2d-40             [-1, 16, 4, 4]              32
#              ReLU-41             [-1, 16, 4, 4]               0
#         Dropout2d-42             [-1, 16, 4, 4]               0
#         AvgPool2d-43             [-1, 16, 1, 1]               0
#            Conv2d-44             [-1, 10, 1, 1]             170
#       BatchNorm2d-45             [-1, 10, 1, 1]              20
#              ReLU-46             [-1, 10, 1, 1]               0
#         Dropout2d-47             [-1, 10, 1, 1]               0
# ================================================================
# Total params: 49,998
# Trainable params: 49,998
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.14
# Params size (MB): 0.19
# Estimated Total Size (MB): 4.34
# ----------------------------------------------------------------

# %%
from dataloader import setup_test_loader, setup_train_loader
from plots import plot_data
from torchvision import transforms
train_transforms = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

test_transforms = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
train_loader = setup_train_loader("data", train_transforms)
test_loader = setup_test_loader("data", test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch.optim as optim
import torch.nn.functional as F
from modelhelper import train_model, test_model
import warnings
warnings.filterwarnings("ignore")
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1, verbose=True)
# New Line
criterion = F.nll_loss
num_epochs = 20
train_loss_per_epoch = []
test_loss_per_epoch = []
train_accuracy_per_epoch = []
test_accuracy_per_epoch = []
for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  print_error = epoch == 1
  [train_accuracy, train_loss] = train_model(model, device, train_loader, optimizer, criterion, print_error)
  train_accuracy_per_epoch.append(train_accuracy)
  train_loss_per_epoch.append(train_loss)

  [test_accuracy, test_loss] = test_model(model, device, test_loader, criterion)
  test_accuracy_per_epoch.append(train_accuracy)
  test_loss_per_epoch.append(train_loss)

  scheduler.step()
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
#   0%|          | 0/391 [00:00<?, ?it/s]WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Train: Loss=1.7861 Batch_id=390 Accuracy=25.09: 100%|██████████| 391/391 [00:09<00:00, 40.54it/s]
# Test set: Average loss: 1.6887, Accuracy: 4095/10000 (40.95%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: Loss=1.5716 Batch_id=390 Accuracy=37.57: 100%|██████████| 391/391 [00:07<00:00, 49.08it/s]
# Test set: Average loss: 1.4751, Accuracy: 4985/10000 (49.85%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: Loss=1.6691 Batch_id=390 Accuracy=42.18: 100%|██████████| 391/391 [00:08<00:00, 48.60it/s]
# Test set: Average loss: 1.3344, Accuracy: 5527/10000 (55.27%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 4
# Train: Loss=1.5914 Batch_id=390 Accuracy=45.99: 100%|██████████| 391/391 [00:07<00:00, 48.98it/s]
# Test set: Average loss: 1.2572, Accuracy: 5841/10000 (58.41%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 5
# Train: Loss=1.5400 Batch_id=390 Accuracy=48.31: 100%|██████████| 391/391 [00:07<00:00, 49.31it/s]
# Test set: Average loss: 1.1612, Accuracy: 6161/10000 (61.61%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 6
# Train: Loss=1.4823 Batch_id=390 Accuracy=49.76: 100%|██████████| 391/391 [00:07<00:00, 48.96it/s]
# Test set: Average loss: 1.1302, Accuracy: 6175/10000 (61.75%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 7
# Train: Loss=1.4360 Batch_id=390 Accuracy=51.19: 100%|██████████| 391/391 [00:08<00:00, 48.04it/s]
# Test set: Average loss: 1.0823, Accuracy: 6420/10000 (64.20%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 8
# Train: Loss=1.3796 Batch_id=390 Accuracy=52.22: 100%|██████████| 391/391 [00:08<00:00, 48.17it/s]
# Test set: Average loss: 1.0545, Accuracy: 6492/10000 (64.92%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 9
# Train: Loss=1.4198 Batch_id=390 Accuracy=52.99: 100%|██████████| 391/391 [00:07<00:00, 49.38it/s]
# Test set: Average loss: 1.0409, Accuracy: 6578/10000 (65.78%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 10
# Train: Loss=1.5003 Batch_id=390 Accuracy=53.93: 100%|██████████| 391/391 [00:07<00:00, 49.23it/s]
# Test set: Average loss: 1.0209, Accuracy: 6630/10000 (66.30%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 11
# Train: Loss=1.3830 Batch_id=390 Accuracy=54.87: 100%|██████████| 391/391 [00:08<00:00, 48.77it/s]
# Test set: Average loss: 1.0067, Accuracy: 6656/10000 (66.56%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 12
# Train: Loss=1.2266 Batch_id=390 Accuracy=55.31: 100%|██████████| 391/391 [00:08<00:00, 48.81it/s]
# Test set: Average loss: 0.9867, Accuracy: 6759/10000 (67.59%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 13
# Train: Loss=1.3325 Batch_id=390 Accuracy=55.66: 100%|██████████| 391/391 [00:07<00:00, 49.03it/s]
# Test set: Average loss: 0.9719, Accuracy: 6770/10000 (67.70%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 14
# Train: Loss=1.3781 Batch_id=390 Accuracy=55.87: 100%|██████████| 391/391 [00:07<00:00, 49.43it/s]
# Test set: Average loss: 0.9686, Accuracy: 6825/10000 (68.25%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 15
# Train: Loss=1.2229 Batch_id=390 Accuracy=56.65: 100%|██████████| 391/391 [00:07<00:00, 49.31it/s]
# Test set: Average loss: 0.9471, Accuracy: 6919/10000 (69.19%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 16
# Train: Loss=1.2897 Batch_id=390 Accuracy=57.75: 100%|██████████| 391/391 [00:08<00:00, 48.57it/s]
# Test set: Average loss: 0.9186, Accuracy: 7019/10000 (70.19%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 17
# Train: Loss=1.1671 Batch_id=390 Accuracy=58.28: 100%|██████████| 391/391 [00:08<00:00, 48.61it/s]
# Test set: Average loss: 0.9092, Accuracy: 7070/10000 (70.70%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 18
# Train: Loss=1.1930 Batch_id=390 Accuracy=58.17: 100%|██████████| 391/391 [00:08<00:00, 47.45it/s]
# Test set: Average loss: 0.8991, Accuracy: 7093/10000 (70.93%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 19
# Train: Loss=1.3817 Batch_id=390 Accuracy=58.49: 100%|██████████| 391/391 [00:08<00:00, 47.74it/s]
# Test set: Average loss: 0.8983, Accuracy: 7074/10000 (70.74%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 20
# Train: Loss=1.2547 Batch_id=390 Accuracy=59.07: 100%|██████████| 391/391 [00:08<00:00, 48.15it/s]
# Test set: Average loss: 0.8936, Accuracy: 7107/10000 (71.07%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
