# %%
from cifar10_base import Net
from common import get_dst_device
from modelhelper import print_model_summary
device = get_dst_device()
model = Net().to(device)
print_model_summary(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             896
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#          Dropout2d-4           [-1, 32, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]           9,248
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#               ReLU-7           [-1, 32, 32, 32]               0
#          Dropout2d-8           [-1, 32, 32, 32]               0
#             Conv2d-9           [-1, 32, 32, 32]           1,056
#       BatchNorm2d-10           [-1, 32, 32, 32]              64
#              ReLU-11           [-1, 32, 32, 32]               0
#         Dropout2d-12           [-1, 32, 32, 32]               0
#         MaxPool2d-13           [-1, 32, 16, 16]               0
#            Conv2d-14           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-15           [-1, 32, 16, 16]              64
#              ReLU-16           [-1, 32, 16, 16]               0
#         Dropout2d-17           [-1, 32, 16, 16]               0
#            Conv2d-18           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-19           [-1, 32, 16, 16]              64
#              ReLU-20           [-1, 32, 16, 16]               0
#         Dropout2d-21           [-1, 32, 16, 16]               0
#            Conv2d-22           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-23           [-1, 32, 16, 16]              64
#              ReLU-24           [-1, 32, 16, 16]               0
#         Dropout2d-25           [-1, 32, 16, 16]               0
#            Conv2d-26           [-1, 32, 16, 16]           1,056
#       BatchNorm2d-27           [-1, 32, 16, 16]              64
#              ReLU-28           [-1, 32, 16, 16]               0
#         Dropout2d-29           [-1, 32, 16, 16]               0
#         MaxPool2d-30             [-1, 32, 8, 8]               0
#            Conv2d-31             [-1, 16, 8, 8]           4,624
#       BatchNorm2d-32             [-1, 16, 8, 8]              32
#              ReLU-33             [-1, 16, 8, 8]               0
#         Dropout2d-34             [-1, 16, 8, 8]               0
#            Conv2d-35             [-1, 16, 6, 6]           2,320
#       BatchNorm2d-36             [-1, 16, 6, 6]              32
#              ReLU-37             [-1, 16, 6, 6]               0
#         Dropout2d-38             [-1, 16, 6, 6]               0
#            Conv2d-39             [-1, 16, 4, 4]           2,320
#       BatchNorm2d-40             [-1, 16, 4, 4]              32
#              ReLU-41             [-1, 16, 4, 4]               0
#         Dropout2d-42             [-1, 16, 4, 4]               0
#         AvgPool2d-43             [-1, 16, 1, 1]               0
#            Conv2d-44             [-1, 10, 1, 1]             170
#       BatchNorm2d-45             [-1, 10, 1, 1]              20
#              ReLU-46             [-1, 10, 1, 1]               0
#         Dropout2d-47             [-1, 10, 1, 1]               0
# ================================================================
# Total params: 49,998
# Trainable params: 49,998
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.14
# Params size (MB): 0.19
# Estimated Total Size (MB): 4.34
# ----------------------------------------------------------------

# %%
from dataloader import setup_test_loader, setup_train_loader
from plots import plot_data
from torchvision import transforms
train_transforms = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

test_transforms = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
train_loader = setup_train_loader("data", train_transforms)
test_loader = setup_test_loader("data", test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch.optim as optim
import torch.nn.functional as F
from modelhelper import train_model, test_model
import warnings
warnings.filterwarnings("ignore")
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1, verbose=True)
# New Line
criterion = F.nll_loss
num_epochs = 20
train_loss_per_epoch = []
test_loss_per_epoch = []
train_accuracy_per_epoch = []
test_accuracy_per_epoch = []
for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  print_error = epoch == 1
  [train_accuracy, train_loss] = train_model(model, device, train_loader, optimizer, criterion, print_error)
  train_accuracy_per_epoch.append(train_accuracy)
  train_loss_per_epoch.append(train_loss)

  [test_accuracy, test_loss] = test_model(model, device, test_loader, criterion)
  test_accuracy_per_epoch.append(train_accuracy)
  test_loss_per_epoch.append(train_loss)

  scheduler.step()
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
#   0%|          | 0/391 [00:00<?, ?it/s]WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Train: Loss=1.7988 Batch_id=390 Accuracy=29.44: 100%|██████████| 391/391 [00:09<00:00, 42.96it/s]
# Test set: Average loss: 1.5700, Accuracy: 4645/10000 (46.45%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: Loss=1.5914 Batch_id=390 Accuracy=40.46: 100%|██████████| 391/391 [00:07<00:00, 49.56it/s]
# Test set: Average loss: 1.3761, Accuracy: 5473/10000 (54.73%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: Loss=1.6396 Batch_id=390 Accuracy=44.56: 100%|██████████| 391/391 [00:07<00:00, 50.55it/s]
# Test set: Average loss: 1.2673, Accuracy: 5887/10000 (58.87%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 4
# Train: Loss=1.6060 Batch_id=390 Accuracy=48.12: 100%|██████████| 391/391 [00:07<00:00, 49.24it/s]
# Test set: Average loss: 1.1779, Accuracy: 6107/10000 (61.07%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 5
# Train: Loss=1.4598 Batch_id=390 Accuracy=50.17: 100%|██████████| 391/391 [00:07<00:00, 49.49it/s]
# Test set: Average loss: 1.1462, Accuracy: 6155/10000 (61.55%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 6
# Train: Loss=1.2309 Batch_id=390 Accuracy=51.37: 100%|██████████| 391/391 [00:07<00:00, 49.69it/s]
# Test set: Average loss: 1.1062, Accuracy: 6294/10000 (62.94%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 7
# Train: Loss=1.2493 Batch_id=390 Accuracy=52.76: 100%|██████████| 391/391 [00:07<00:00, 49.84it/s]
# Test set: Average loss: 1.0635, Accuracy: 6520/10000 (65.20%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 8
# Train: Loss=1.2754 Batch_id=390 Accuracy=53.84: 100%|██████████| 391/391 [00:08<00:00, 48.47it/s]
# Test set: Average loss: 1.0196, Accuracy: 6680/10000 (66.80%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 9
# Train: Loss=1.2068 Batch_id=390 Accuracy=54.58: 100%|██████████| 391/391 [00:07<00:00, 49.44it/s]
# Test set: Average loss: 1.0034, Accuracy: 6748/10000 (67.48%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 10
# Train: Loss=1.2923 Batch_id=390 Accuracy=55.44: 100%|██████████| 391/391 [00:07<00:00, 49.12it/s]
# Test set: Average loss: 0.9874, Accuracy: 6811/10000 (68.11%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 11
# Train: Loss=1.3139 Batch_id=390 Accuracy=55.44: 100%|██████████| 391/391 [00:07<00:00, 49.71it/s]
# Test set: Average loss: 0.9626, Accuracy: 6877/10000 (68.77%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 12
# Train: Loss=1.0872 Batch_id=390 Accuracy=56.32: 100%|██████████| 391/391 [00:08<00:00, 48.69it/s]
# Test set: Average loss: 0.9524, Accuracy: 6947/10000 (69.47%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 13
# Train: Loss=1.4709 Batch_id=390 Accuracy=56.44: 100%|██████████| 391/391 [00:07<00:00, 49.81it/s]
# Test set: Average loss: 0.9479, Accuracy: 6892/10000 (68.92%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 14
# Train: Loss=1.3972 Batch_id=390 Accuracy=57.22: 100%|██████████| 391/391 [00:07<00:00, 49.54it/s]
# Test set: Average loss: 0.9255, Accuracy: 7018/10000 (70.18%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 15
# Train: Loss=0.9507 Batch_id=390 Accuracy=57.38: 100%|██████████| 391/391 [00:07<00:00, 49.92it/s]
# Test set: Average loss: 0.9381, Accuracy: 6951/10000 (69.51%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 16
# Train: Loss=1.0755 Batch_id=390 Accuracy=58.73: 100%|██████████| 391/391 [00:07<00:00, 49.50it/s]
# Test set: Average loss: 0.8898, Accuracy: 7121/10000 (71.21%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 17
# Train: Loss=1.2972 Batch_id=390 Accuracy=59.28: 100%|██████████| 391/391 [00:07<00:00, 49.59it/s]
# Test set: Average loss: 0.8790, Accuracy: 7187/10000 (71.87%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 18
# Train: Loss=1.3163 Batch_id=390 Accuracy=59.18: 100%|██████████| 391/391 [00:07<00:00, 50.57it/s]
# Test set: Average loss: 0.8748, Accuracy: 7191/10000 (71.91%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 19
# Train: Loss=1.3350 Batch_id=390 Accuracy=59.35: 100%|██████████| 391/391 [00:08<00:00, 48.03it/s]
# Test set: Average loss: 0.8736, Accuracy: 7196/10000 (71.96%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 20
# Train: Loss=1.3661 Batch_id=390 Accuracy=59.79: 100%|██████████| 391/391 [00:08<00:00, 48.61it/s]
# Test set: Average loss: 0.8717, Accuracy: 7197/10000 (71.97%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
